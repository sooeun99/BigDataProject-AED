# %% [markdown]
# ## 급성심정지환자
# - 데이터
#     - 서울시_구별_급성심정지환자(발생지기준).csv
#     - 서울시_환자발생지별_급성심정지환자_성별.csv
#     - 서울시_환자발생지별_급성심정지환자_연령대.csv
#     - 서울시_환자발생지별_급성심정지환자_급성심정지환자수.csv
#     - 서울시_환자발생지별_급성심정지환자_발생장소.csv
#     - 서울시_환자발생지별_급성심정지환자_시행종류.csv
#     - 서울시_환자발생지별_급성심정지환자_최종.csv

# %%
import pandas as pd
import numpy as np
from functools import reduce

# %% [markdown]
# ## 환자발생지 기준

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
live = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
live

# %% [markdown]
# ### 1. 소재지(환자발생지_시군구) 기준으로 성별 value_count

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
gender = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
gender

# %%
# 2018 남성
gender1_2018 = gender[(gender['발생년도']==2018) & (gender['성별']=='남성')]
live_gender1_2018 = gender1_2018[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender1_2018 = live_gender1_2018[['소재지','count']]
new_live_gender1_2018.rename(columns={'count': "2018_male_count",
                               '소재지':'발생지소재지'},inplace=True)
#new_live_gender1_2018 = new_live_gender1_2018.drop([new_live_gender1_2018.index[13]])
#new_live_gender1_2018.reset_index(drop=True, inplace=True)
new_live_gender1_2018

# 2019 남성
gender1_2019 = gender[(gender['발생년도']==2019) & (gender['성별']=='남성')]
live_gender1_2019 = gender1_2019[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender1_2019 = live_gender1_2019[['소재지','count']]
new_live_gender1_2019.rename(columns={'count': "2019_male_count",
                               '소재지':'발생지소재지'},inplace=True)
#new_live_gender1_2019 = new_live_gender1_2019.drop([new_live_gender1.index[13]])
#new_live_gender1_2019.reset_index(drop=True, inplace=True)
new_live_gender1_2019

# 2020 남성 
gender1_2020 = gender[(gender['발생년도']==2020) & (gender['성별']=='남성')]
live_gender1_2020 = gender1_2020[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender1_2020 = live_gender1_2020[['소재지','count']]
new_live_gender1_2020.rename(columns={'count': "2020_male_count",
                               '소재지':'발생지소재지'},inplace=True)
# new_live_gender1_2020 = new_live_gender1_2020.drop([new_live_gender1.index[13]])
# new_live_gender1_2020.reset_index(drop=True, inplace=True)
new_live_gender1_2020

# %%
data_gender = pd.merge(new_live_gender1_2018, new_live_gender1_2019 , on='발생지소재지', how='right')
data_gender2 = pd.merge(data_gender, new_live_gender1_2020 , on='발생지소재지', how='right')
data_gender2['male_count_mean'] = data_gender2[['2018_male_count','2019_male_count', '2020_male_count']].mean(axis=1).round(1)
data_gender2

# %%
# 2018 여성
gender2_2018 = gender[(gender['발생년도']<=2018) & (gender['성별']=='여성')]
live_gender2_2018 = gender2_2018[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender2_2018 = live_gender2_2018[['소재지','count']]
new_live_gender2_2018.rename(columns={'count': "2018_female_count",
                                '소재지':'발생지소재지'},inplace=True)
new_live_gender2_2018

# 2019 여성
gender2_2019 = gender[(gender['발생년도']<=2018) & (gender['성별']=='여성')]
live_gender2_2019 = gender2_2019[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender2_2019 = live_gender2_2019[['소재지','count']]
new_live_gender2_2019.rename(columns={'count': "2019_female_count",
                                '소재지':'발생지소재지'},inplace=True)
new_live_gender2_2019

# 2020 여성
gender2_2020 = gender[(gender['발생년도']<=2018) & (gender['성별']=='여성')]
live_gender2_2020 = gender2_2020[['소재지','성별']].groupby(['소재지'],as_index=False).value_counts()
new_live_gender2_2020 = live_gender2_2020[['소재지','count']]
new_live_gender2_2020.rename(columns={'count': "2020_female_count",
                                '소재지':'발생지소재지'},inplace=True)
new_live_gender2_2020

# %%
data2_gender = pd.merge(new_live_gender2_2018, new_live_gender2_2019 , on='발생지소재지', how='right')
data2_gender2 = pd.merge(data2_gender, new_live_gender2_2020 , on='발생지소재지', how='right')
data2_gender2['female_count_mean'] = data2_gender2[['2018_female_count','2019_female_count', '2020_female_count']].mean(axis=1).round(1)
data2_gender2

# %%
# 성별 데이터 합치기 
live_gender = pd.merge(data_gender2, data2_gender2 , on='발생지소재지', how='right')
live_gender

# %%
# 저장 후 주석처리
# live_gender.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_성별.csv")

# %% [markdown]
# ### 2. 소재지(환자발생지_시군구) 기준으로 연령대 value_count

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
age = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
age

# %%
# 2018 연령대
age1_2018 = age[(age['발생년도']<=2018) & (age['연령대'] == '노년')]
live_age1_2018 = age1_2018[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age1_2018 = live_age1_2018[['소재지','count']]
new_live_age1_2018.rename(columns={'count': "2018_노년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age1_2018

# 2018 연령대
age2_2018 = age[(age['발생년도']<=2018) & (age['연령대'] == '장년')]
live_age2_2018 = age2_2018[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age2_2018 = live_age1_2018[['소재지','count']]
new_live_age2_2018.rename(columns={'count': "2018_장년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age2_2018

# 2018 연령대
age3_2018 = age[(age['발생년도']<=2018) & (age['연령대'] == '중년')]
live_age3_2018 = age3_2018[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age3_2018 = live_age3_2018[['소재지','count']]
new_live_age3_2018.rename(columns={'count': "2018_중년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age3_2018 = new_live_age3_2018.drop([new_live_age3_2018.index[13]])
#new_live_age3_2018.reset_index(drop=True, inplace=True)
new_live_age3_2018

# 2018 연령대
age4_2018 = age[(age['발생년도']<=2018) & (age['연령대'] == '청년')]
live_age4_2018 = age4_2018[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age4_2018 = live_age4_2018[['소재지','count']]
new_live_age4_2018.rename(columns={'count': "2018_청년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age4_2018

# 2018 연령대
age5_2018 = age[(age['발생년도']<=2018) & (age['연령대'] == '소아청소년')]
live_age5_2018 = age5_2018[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age5_2018 = live_age5_2018[['소재지','count']]
new_live_age5_2018.rename(columns={'count': "2018_소아청소년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age5_2018

# %%
# 결측데이터확인 후 데이터 합치기 
data1 = pd.concat([new_live_age1_2018,new_live_age2_2018,new_live_age3_2018,new_live_age4_2018,new_live_age5_2018], axis=1)
data1['2018_소아청소년'] = data1['2018_소아청소년'].fillna(0.0)
data1 = data1.iloc[:,[0,1,3,5,7,9]]
data1

# %%
# 2019 연령대
age1_2019 = age[(age['발생년도']==2019) & (age['연령대'] == '노년')]
live_age1_2019 = age1_2019[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age1_2019 = live_age1_2019[['소재지','count']]
new_live_age1_2019.rename(columns={'count': "2019_노년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2019 = new_live_age1_2019.drop([new_live_age1_2019.index[13]])
#new_live_age1_2019.reset_index(drop=True, inplace=True)
new_live_age1_2019

# 2019 연령대
age2_2019 = age[(age['발생년도']==2019) & (age['연령대'] == '장년')]
live_age2_2019 = age2_2019[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age2_2019 = live_age2_2019[['소재지','count']]
new_live_age2_2019.rename(columns={'count': "2019_장년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age2_2019 = new_live_age2_2019.drop([new_live_age2_2019.index[13]])
#new_live_age2_2019.reset_index(drop=True, inplace=True)
new_live_age2_2019

# 2019 연령대
age3_2019 = age[(age['발생년도']==2019) & (age['연령대'] == '중년')]
live_age3_2019 = age3_2019[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age3_2019 = live_age3_2019[['소재지','count']]
new_live_age3_2019.rename(columns={'count': "2019_중년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age3_2019 = new_live_age3_2018.drop([new_live_age3_2018.index[13]])
#new_live_age3_2019.reset_index(drop=True, inplace=True)
new_live_age3_2019

# 2019 연령대
age4_2019 = age[(age['발생년도']==2019) & (age['연령대'] == '청년')]
live_age4_2019 = age4_2019[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age4_2019 = live_age4_2019[['소재지','count']]
new_live_age4_2019.rename(columns={'count': "2019_청년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age4_2019

# 2019 연령대
age5_2019 = age[(age['발생년도']==2019) & (age['연령대'] == '소아청소년')]
live_age5_2019 = age5_2019[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age5_2019 = live_age5_2019[['소재지','count']]
new_live_age5_2019.rename(columns={'count': "2019_소아청소년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age5_2019

# %%
# 결측데이터확인 후 데이터 합치기 
data2 = pd.concat([new_live_age1_2019,new_live_age2_2019,new_live_age3_2019,new_live_age4_2019,new_live_age5_2019], axis=1)
data2['2019_소아청소년'] = data2['2019_소아청소년'].fillna(0.0)
data2 = data2.iloc[:,[0,1,3,5,7,9]]
data2

# %%
# 2020 연령대
age1_2020 = age[(age['발생년도']==2020) & (age['연령대'] == '노년')]
live_age1_2020 = age1_2020[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age1_2020 = live_age1_2020[['소재지','count']]
new_live_age1_2020.rename(columns={'count': "2020_노년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age1_2020

# 2020 연령대
age2_2020 = age[(age['발생년도']==2020) & (age['연령대'] == '장년')]
live_age2_2020 = age2_2020[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age2_2020 = live_age2_2020[['소재지','count']]
new_live_age2_2020.rename(columns={'count': "2020_장년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age2_2020

# 2020 연령대
age3_2020 = age[(age['발생년도']==2020) & (age['연령대'] == '중년')]
live_age3_2020 = age3_2020[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age3_2020 = live_age3_2020[['소재지','count']]
new_live_age3_2020.rename(columns={'count': "2020_중년",
                                '소재지':'발생지소재지'},inplace=True)
# new_live_age3_2020 = new_live_age3_2020.drop([new_live_age3_2020.index[13]])
# new_live_age3_2020.reset_index(drop=True, inplace=True)
new_live_age3_2020

# 2020 연령대
age4_2020 = age[(age['발생년도']==2020) & (age['연령대'] == '청년')]
live_age4_2020 = age4_2020[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age4_2020 = live_age4_2020[['소재지','count']]
new_live_age4_2020.rename(columns={'count': "2020_청년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age4_2020

# 2020 연령대
age5_2020 = age[(age['발생년도']==2020) & (age['연령대'] == '소아청소년')]
live_age5_2020 = age5_2020[['소재지','연령대']].groupby(['소재지'],as_index=False).value_counts()
new_live_age5_2020 = live_age5_2020[['소재지','count']]
new_live_age5_2020.rename(columns={'count': "2020_소아청소년",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_age1_2018 = new_live_age1_2018.drop([new_live_age1_2018.index[13]])
#new_live_age1_2018.reset_index(drop=True, inplace=True)
new_live_age5_2020

# %%
# 결측데이터확인 후 데이터 합치기 
data3 = pd.concat([new_live_age1_2020,new_live_age2_2020,new_live_age3_2020,new_live_age4_2020,new_live_age5_2020], axis=1)
data3['2020_소아청소년'] = data3['2020_소아청소년'].fillna(0)
data3 = data3.iloc[:,[0,1,3,5,7,9]]
data3

# %%
data_list = [data1,data2,data3]
data_age = reduce(lambda x,y : pd.merge(x,y,on='발생지소재지'),data_list)
data_age

# %%
data_age['노년_mean'] = data_age[['2018_노년','2019_노년','2020_노년']].mean(axis=1).round(1)
data_age['장년_mean'] = data_age[['2018_장년','2019_장년','2020_장년']].mean(axis=1).round(1)
data_age['중년_mean'] = data_age[['2018_중년','2019_중년','2020_중년']].mean(axis=1).round(1)
data_age['청년_mean'] = data_age[['2018_청년','2019_청년','2020_청년']].mean(axis=1).round(1)
data_age['소아청소년_mean'] = data_age[['2018_소아청소년','2019_소아청소년','2020_소아청소년']].mean(axis=1).round(1)
data_age

# %%
# 저장 후 주석처리 
# data_age.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_연령대.csv")

# %% [markdown]
# ### 3. 소재지(환자발생지_시군구) 기준으로 급성심정지환자수 value_count

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
count = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
count

# %%
# 2018년 급성심정지환자수 
count_2018 = count[count['발생년도']==2018]
live_count_2018 = count_2018['소재지'].value_counts().to_frame().reset_index()
#live_count_2018 = live_count_2018.drop([live_count_2018.index[25]])
#live_count_2018.reset_index(drop=True, inplace=True)
live_count_2018.rename(columns={"index": "발생지소재지",
                           "소재지":"2018_arrest_count"},inplace=True)
live_count_2018 = live_count_2018.sort_values(by='발생지소재지', ascending=True).reset_index()
live_count_2018 = live_count_2018.drop(['index'],axis=1)
live_count_2018

# 2019년 급성심정지환자수 
count_2019 = count[count['발생년도']==2019]
live_count_2019 = count_2019['소재지'].value_counts().to_frame().reset_index()
#live_count_2019 = live_count_2019.drop([live_count_2019.index[25]])
#live_count_2019.reset_index(drop=True, inplace=True)
live_count_2019.rename(columns={"index": "발생지소재지",
                           "소재지":"2019_arrest_count"},inplace=True)
live_count_2019 = live_count_2019.sort_values(by='발생지소재지', ascending=True).reset_index()
live_count_2019 = live_count_2019.drop(['index'],axis=1)
live_count_2019

# 2020년 급성심정지환자수 
count_2020 = count[count['발생년도']==2020]
live_count_2020 = count_2020['소재지'].value_counts().to_frame().reset_index()
live_count_2020.reset_index(drop=True, inplace=True)
live_count_2020.rename(columns={"index": "발생지소재지",
                           "소재지":"2020_arrest_count"},inplace=True)
live_count_2020 = live_count_2020.sort_values(by='발생지소재지', ascending=True).reset_index()
live_count_2020 = live_count_2020.drop(['index'],axis=1)
live_count_2020

# %%
# 결측데이터확인 후 데이터 합치기 
data = pd.concat([live_count_2018,live_count_2019,live_count_2020], axis=1)
data = data.iloc[:,[0,1,3,5]]
data

# %%
data['arrest_count_mean'] = data[['2018_arrest_count','2019_arrest_count','2020_arrest_count']].mean(axis=1).round(1)
data

# %%
# 저장 후 주석처리 
# data.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_급성심정지환자수.csv")

# %% [markdown]
# ### 4. 소재지(환자발생지_시군구) 기준으로 공공장소,비공공장소 value_count

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
place = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
place

# %%
# 2018년 발생장소 
place1_2018 = place[(place['발생장소'] == '비공공장소') & (place['발생년도']==2018)]
live_place1_2018 = place1_2018[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place1_2018 = live_place1_2018[['소재지','count']]
new_live_place1_2018.rename(columns={'count': "2018_비공공장소",
                                '소재지':'발생지소재지'},inplace=True)
new_live_place1_2018

# 2018년 발생장소
place2_2018 = place[(place['발생장소'] == '미상') & (place['발생년도']==2018)]
live_place2_2018 = place2_2018[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place2_2018 = live_place2_2018[['소재지','count']]
new_live_place2_2018.rename(columns={'count': "2018_미상",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_place2_2018 = new_live_place2_2018.drop([new_live_place2_2018.index[13]])
#new_live_place2_2018.reset_index(drop=True, inplace=True)
new_live_place2_2018

# 2018년 발생장소
place3_2018 = place[(place['발생장소'] == '공공장소') & (place['발생년도']==2018)]
live_place3_2018 = place3_2018[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place3_2018 = live_place3_2018[['소재지','count']]
new_live_place3_2018.rename(columns={'count': "2018_공공장소",
                                '소재지':'발생지소재지'},inplace=True)
# new_live_place3_2018 = new_live_place3_2018.drop([new_live_place2_2018.index[13]])
# new_live_place3_2018.reset_index(drop=True, inplace=True)
new_live_place3_2018

# %%
# 2019년 발생장소 
place1_2019 = place[(place['발생장소'] == '비공공장소') & (place['발생년도']==2019)]
live_place1_2019 = place1_2019[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place1_2019 = live_place1_2019[['소재지','count']]
new_live_place1_2019.rename(columns={'count': "2019_비공공장소",
                                '소재지':'발생지소재지'},inplace=True)
new_live_place1_2019

# 2019년 발생장소
place2_2019 = place[(place['발생장소'] == '미상') & (place['발생년도']==2019)]
live_place2_2019 = place2_2019[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place2_2019 = live_place2_2019[['소재지','count']]
new_live_place2_2019.rename(columns={'count': "2019_미상",
                                '소재지':'발생지소재지'},inplace=True)
# new_live_place2_2019 = new_live_place2_2019.drop([new_live_place2_2019.index[13]])
# new_live_place2_2019.reset_index(drop=True, inplace=True)
new_live_place2_2019

# 2018년 발생장소
place3_2019 = place[(place['발생장소'] == '공공장소') & (place['발생년도']==2019)]
live_place3_2019 = place3_2019[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place3_2019 = live_place3_2019[['소재지','count']]
new_live_place3_2019.rename(columns={'count': "2019_공공장소",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_place3_2019 = new_live_place3_2019.drop([new_live_place2_2019.index[13]])
#new_live_place3_2019.reset_index(drop=True, inplace=True)
new_live_place3_2019

# %%
# 2020년 발생장소 
place1_2020 = place[(place['발생장소'] == '비공공장소') & (place['발생년도']==2020)]
live_place1_2020 = place1_2020[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place1_2020 = live_place1_2020[['소재지','count']]
new_live_place1_2020.rename(columns={'count': "2020_비공공장소",
                                '소재지':'발생지소재지'},inplace=True)
new_live_place1_2020

# 2020년 발생장소
place2_2020 = place[(place['발생장소'] == '미상') & (place['발생년도']==2020)]
live_place2_2020 = place2_2020[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place2_2020 = live_place2_2020[['소재지','count']]
new_live_place2_2020.rename(columns={'count': "2020_미상",
                                '소재지':'발생지소재지'},inplace=True)
# new_live_place2_2019 = new_live_place2_2019.drop([new_live_place2_2019.index[13]])
# new_live_place2_2019.reset_index(drop=True, inplace=True)
new_live_place2_2020

# 2020년 발생장소
place3_2020 = place[(place['발생장소'] == '공공장소') & (place['발생년도']==2020)]
live_place3_2020 = place3_2020[['소재지','발생장소']].groupby(['소재지'],as_index=False).value_counts()
new_live_place3_2020 = live_place3_2020[['소재지','count']]
new_live_place3_2020.rename(columns={'count': "2020_공공장소",
                                '소재지':'발생지소재지'},inplace=True)
# new_live_place3_2020 = new_live_place3_2020.drop([new_live_place2_2020.index[13]])
# new_live_place3_2020.reset_index(drop=True, inplace=True)
new_live_place3_2020

# %%
# 결측데이터확인 후 데이터 합치기 
data = pd.concat([new_live_place1_2018,new_live_place2_2018,new_live_place3_2018], axis=1)
#data3['2020_소아청소년'] = data3['2020_소아청소년'].fillna(0.0)
data = data.iloc[:,[0,1,3,5]]
data

# %%
# 결측데이터확인 후 데이터 합치기 
data2 = pd.concat([new_live_place1_2019,new_live_place2_2019,new_live_place3_2019], axis=1)
data2 = data2.iloc[:,[0,1,3,5]]
data2

# %%
# 결측데이터확인 후 데이터 합치기 
data3 = pd.concat([new_live_place1_2020,new_live_place2_2020,new_live_place3_2020], axis=1)
data3 = data3.iloc[:,[0,1,3,5]]
data3

# %%
data_place = pd.concat([data,data2,data3], axis=1)
data_place = data_place.iloc[:,[0,1,2,3,5,6,7,9,10,11]]
data_place
# Out:
#    발생지소재지  2018_비공공장소  2018_미상  2018_공공장소  2019_비공공장소  2019_미상  2019_공공장소  \
# 0     강남구         155       21         57         124       30         49
# 1     강동구         111       53         44         100       62         25
# 2     강북구         149       11         40         130       17         22
# 3     강서구         157       50         40         150       57         38
# 4     관악구         166       30         31         110       42         28
# 5     광진구         138       24         24         123       12         17
# 6     구로구         115       39         31         108       77         29
# 7     금천구          64       24         22          60       34         22
# 8     노원구         195       37         43         182       52         32
# 9     도봉구         158        9         29         157       12         15
# 10   동대문구         125       22         39         103       46         34
# 11    동작구         117       19         21          85       35         26
# ...

# %%
data_place['비공공장소_mean'] = data_place[['2018_비공공장소','2019_비공공장소','2020_비공공장소']].mean(axis=1).round(1)
data_place['미상_mean'] = data_place[['2018_미상','2019_미상','2020_미상']].mean(axis=1).round(1)
data_place['공공장소_mean'] = data_place[['2018_공공장소','2019_공공장소','2020_공공장소']].mean(axis=1).round(1)
data_place
# Out:
#    발생지소재지  2018_비공공장소  2018_미상  2018_공공장소  2019_비공공장소  2019_미상  2019_공공장소  \
# 0     강남구         155       21         57         124       30         49
# 1     강동구         111       53         44         100       62         25
# 2     강북구         149       11         40         130       17         22
# 3     강서구         157       50         40         150       57         38
# 4     관악구         166       30         31         110       42         28
# 5     광진구         138       24         24         123       12         17
# 6     구로구         115       39         31         108       77         29
# 7     금천구          64       24         22          60       34         22
# 8     노원구         195       37         43         182       52         32
# 9     도봉구         158        9         29         157       12         15
# 10   동대문구         125       22         39         103       46         34
# 11    동작구         117       19         21          85       35         26
# ...

# %%
# 저장 후 주석처리 
# data_place.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_발생장소.csv")

# %% [markdown]
# ### 5. 소재지(환자발생지_시군구) 기준으로 심폐소생술시행종류 value_count

# %%
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
type = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_구별_급성심정지환자(발생지기준).csv",index_col = 0)
type
# Out:
#        발생년도 환자발생장소_시도  소재지  성별  연령(만) 연령대 환자거주지_시도 환자거주지_시군구   발생장소 시행종류
# 0      2018        서울  용산구  여성     83  노년       서울       용산구  비공공장소   NO
# 1      2018        서울   중구  여성     67  노년       서울        중구  비공공장소   NO
# 2      2018        서울   중구  남성     46  중년       서울       노원구   공공장소   NO
# 3      2018        서울  동작구  남성     91  노년       서울       동작구  비공공장소  CPR
# 4      2018        서울  동작구  여성     61  장년       서울       동작구  비공공장소  CPR
# ...     ...       ...  ...  ..    ...  ..      ...       ...    ...  ...
# 13408  2020        서울  성동구  남성     79  노년       서울       성동구     미상   NO
# 13409  2020        서울  성동구  남성     37  중년       경기   수원시 장안구     미상   NO
# 13410  2020        서울  성동구  남성     67  노년       서울       성동구  비공공장소   NO
# 13411  2020        서울  성동구  여성     68  노년       서울       성동구     미상   NO
# 13412  2020        서울  금천구  여성     92  노년       서울       금천구     미상   NO
#
# [13413 rows x 10 columns]

# %%
# 2018년 시행종류
type1_2018 = type[(type['발생년도']==2018) & (type['시행종류'] == 'NO')]
live_type1_2018 = type1_2018[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type1_2018 = live_type1_2018[['소재지','count']]
new_live_type1_2018.rename(columns={'count': "2018_AED_NO",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type1_2018 = new_live_type1_2018.drop([new_live_type1_2018.index[13]])
#new_live_type1_2018.reset_index(drop=True, inplace=True)
new_live_type1_2018

## 2018년 시행종류
type2_2018 = type[(type['발생년도']==2018) & (type['시행종류'] == 'CPR')]
live_type2_2018 = type2_2018[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type2_2018 = live_type2_2018[['소재지','count']]
new_live_type2_2018.rename(columns={'count': "2018_CPR",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type2_2018 = new_live_type2_2018.drop([new_live_type2_2018.index[13]])
#new_live_type2_2018.reset_index(drop=True, inplace=True)
new_live_type2_2018

# 2018년 시행종류
type3_2018 = type[(type['발생년도']==2018) & (type['시행종류'] == 'CPR+AED')]
live_type3_2018 = type3_2018[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type3_2018= live_type3_2018[['소재지','count']]
new_live_type3_2018.rename(columns={'count': "2018_CPR+AED",
                                '소재지':'발생지소재지'},inplace=True)
new_live_type3_2018
# Out:
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\3979160261.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type1_2018.rename(columns={'count': "2018_AED_NO",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\3979160261.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type2_2018.rename(columns={'count': "2018_CPR",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\3979160261.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 결측데이터확인 후 데이터 합치기 
data1 = pd.concat([new_live_type1_2018,new_live_type2_2018,new_live_type3_2018], axis=1)
data1['2018_CPR+AED'] = data1['2018_CPR+AED'].fillna(0.0)
data1 = data1.iloc[:,[0,1,3,5]]
data1
# Out:
#    발생지소재지  2018_AED_NO  2018_CPR  2018_CPR+AED
# 0     강남구          111       121           1.0
# 1     강동구          169        39           2.0
# 2     강북구          124        76           1.0
# 3     강서구          195        52           3.0
# 4     관악구          138        87           1.0
# 5     광진구          100        86           3.0
# 6     구로구          123        61           1.0
# 7     금천구           92        18           1.0
# 8     노원구          212        60           1.0
# 9     도봉구          119        76           3.0
# 10   동대문구          127        56           0.0
# 11    동작구           91        66           0.0
# 12    마포구           93        63           0.0
# 13   서대문구           93        76           0.0
# 14    서초구           89        81           0.0
# 15    성동구          100        48           0.0
# 16    성북구          109        69           0.0
# 17    송파구          154       111           0.0
# 18    양천구          145        35           0.0
# ...

# %%
# 2019년 시행종류
type1_2019 = type[(type['발생년도']==2019) & (type['시행종류'] == 'NO')]
live_type1_2019 = type1_2019[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type1_2019 = live_type1_2019[['소재지','count']]
new_live_type1_2019.rename(columns={'count': "2019_AED_NO",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type1_2019 = new_live_type1_2019.drop([new_live_type1_2019.index[13]])
#new_live_type1_2019.reset_index(drop=True, inplace=True)
new_live_type1_2019

## 2019년 시행종류
type2_2019 = type[(type['발생년도']==2019) & (type['시행종류'] == 'CPR')]
live_type2_2019 = type2_2019[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type2_2019 = live_type2_2019[['소재지','count']]
new_live_type2_2019.rename(columns={'count': "2019_CPR",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type2_2019 = new_live_type2_2019.drop([new_live_type2_2019.index[13]])
#new_live_type2_2019.reset_index(drop=True, inplace=True)
new_live_type2_2019

# 2019년 시행종류
type3_2019 = type[(type['발생년도']==2019) & (type['시행종류'] == 'CPR+AED')]
live_type3_2019 = type3_2019[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type3_2019= live_type3_2019[['소재지','count']]
new_live_type3_2019.rename(columns={'count': "2019_CPR+AED",
                                '소재지':'발생지소재지'},inplace=True)
new_live_type3_2019
# Out:
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\1977519818.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type1_2019.rename(columns={'count': "2019_AED_NO",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\1977519818.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type2_2019.rename(columns={'count': "2019_CPR",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\1977519818.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 결측데이터확인 후 데이터 합치기 
data2 = pd.concat([new_live_type1_2019,new_live_type2_2019,new_live_type3_2019], axis=1)
data2['2019_CPR+AED'] = data2['2019_CPR+AED'].fillna(0.0)
data2 = data2.iloc[:,[0,1,3,5]]
data2
# Out:
#    발생지소재지  2019_AED_NO  2019_CPR  2019_CPR+AED
# 0     강남구          103        96           4.0
# 1     강동구          154        32           1.0
# 2     강북구          117        52           1.0
# 3     강서구          195        49           2.0
# 4     관악구          100        78           1.0
# 5     광진구           83        69           1.0
# 6     구로구          129        85           1.0
# 7     금천구           97        19           5.0
# 8     노원구          207        59           2.0
# 9     도봉구          122        61           1.0
# 10   동대문구          136        46           1.0
# 11    동작구           85        60           2.0
# 12    마포구           97        99           1.0
# 13   서대문구           75        57           0.0
# 14    서초구          105        76           0.0
# 15    성동구           91        50           0.0
# 16    성북구          123        72           0.0
# 17    송파구          134        89           0.0
# 18    양천구          121        56           0.0
# ...

# %%
# 2020년 시행종류
type1_2020 = type[(type['발생년도']==2020) & (type['시행종류'] == 'NO')]
live_type1_2020 = type1_2020[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type1_2020 = live_type1_2020[['소재지','count']]
new_live_type1_2020.rename(columns={'count': "2020_AED_NO",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type1_2020 = new_live_type1_2020.drop([new_live_type1_2020.index[13]])
#new_live_type1_2020.reset_index(drop=True, inplace=True)
new_live_type1_2020

## 2020년 시행종류
type2_2020 = type[(type['발생년도']==2020) & (type['시행종류'] == 'CPR')]
live_type2_2020 = type2_2020[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type2_2020 = live_type2_2020[['소재지','count']]
new_live_type2_2020.rename(columns={'count': "2020_CPR",
                                '소재지':'발생지소재지'},inplace=True)
#new_live_type2_2020 = new_live_type2_2020.drop([new_live_type2_2020.index[13]])
#new_live_type2_2020.reset_index(drop=True, inplace=True)
new_live_type2_2020

# 2020년 시행종류
type3_2020 = type[(type['발생년도']==2020) & (type['시행종류'] == 'CPR+AED')]
live_type3_2020 = type3_2020[['소재지','시행종류']].groupby(['소재지'],as_index=False).value_counts()
new_live_type3_2020= live_type3_2020[['소재지','count']]
new_live_type3_2020.rename(columns={'count': "2020_CPR+AED",
                                '소재지':'발생지소재지'},inplace=True)
new_live_type3_2020
# Out:
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\2317327845.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type1_2020.rename(columns={'count': "2020_AED_NO",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\2317327845.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_live_type2_2020.rename(columns={'count': "2020_CPR",
# C:\Users\ppi06\AppData\Local\Temp\ipykernel_23032\2317327845.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# 결측데이터확인 후 데이터 합치기 
data3 = pd.concat([new_live_type1_2020,new_live_type2_2020,new_live_type3_2020], axis=1)
data3['2020_CPR+AED'] = data3['2020_CPR+AED'].fillna(0.0)
data3 = data3.iloc[:,[0,1,3,5]]
data3
# Out:
#    발생지소재지  2020_AED_NO  2020_CPR  2020_CPR+AED
# 0     강남구          138        86           2.0
# 1     강동구          122        69           2.0
# 2     강북구          118        77           1.0
# 3     강서구          212        39           1.0
# 4     관악구          109        77           1.0
# 5     광진구           73        80           2.0
# 6     구로구          103        55           2.0
# 7     금천구           75        35           0.0
# 8     노원구          174        58           0.0
# 9     도봉구          111        61           0.0
# 10   동대문구          135        53           0.0
# 11    동작구           95        61           0.0
# 12    마포구           95        76           0.0
# 13   서대문구           92        59           0.0
# 14    서초구           93        67           0.0
# 15    성동구           88        60           0.0
# 16    성북구          131        66           0.0
# 17    송파구          126       142           0.0
# 18    양천구          106        28           0.0
# ...

# %%
data_type = pd.concat([data1,data2,data3], axis=1)
data_type = data_type.iloc[:,[0,1,2,3,5,6,7,9,10,11]]
data_type
# Out:
#    발생지소재지  2018_AED_NO  2018_CPR  2018_CPR+AED  2019_AED_NO  2019_CPR  \
# 0     강남구          111       121           1.0          103        96
# 1     강동구          169        39           2.0          154        32
# 2     강북구          124        76           1.0          117        52
# 3     강서구          195        52           3.0          195        49
# 4     관악구          138        87           1.0          100        78
# 5     광진구          100        86           3.0           83        69
# 6     구로구          123        61           1.0          129        85
# 7     금천구           92        18           1.0           97        19
# 8     노원구          212        60           1.0          207        59
# 9     도봉구          119        76           3.0          122        61
# 10   동대문구          127        56           0.0          136        46
# 11    동작구           91        66           0.0           85        60
# ...

# %%
data_type['AED_NO_mean'] = data_type[['2018_AED_NO','2019_AED_NO','2020_AED_NO']].mean(axis=1).round(1)
data_type['CPR_mean'] = data_type[['2018_CPR','2019_CPR','2020_CPR']].mean(axis=1).round(1)
data_type['CPR+AED_mean'] = data_type[['2018_CPR+AED','2019_CPR+AED','2020_CPR+AED']].mean(axis=1).round(1)
data_type
# Out:
#    발생지소재지  2018_AED_NO  2018_CPR  2018_CPR+AED  2019_AED_NO  2019_CPR  \
# 0     강남구          111       121           1.0          103        96
# 1     강동구          169        39           2.0          154        32
# 2     강북구          124        76           1.0          117        52
# 3     강서구          195        52           3.0          195        49
# 4     관악구          138        87           1.0          100        78
# 5     광진구          100        86           3.0           83        69
# 6     구로구          123        61           1.0          129        85
# 7     금천구           92        18           1.0           97        19
# 8     노원구          212        60           1.0          207        59
# 9     도봉구          119        76           3.0          122        61
# 10   동대문구          127        56           0.0          136        46
# 11    동작구           91        66           0.0           85        60
# ...

# %%
# 저장 후 주석처리 
# data_type.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_시행종류.csv")

# %%
# 데이터 
# 서울시_환자발생지별_급성심정지환자_성별.csv
# 서울시_환자발생지별_급성심정지환자_연령대.csv
# 서울시_환자발생지별_급성심정지환자_급성심정지환자수.csv
# 서울시_환자발생지별_급성심정지환자_발생장소.csv
# 서울시_환자발생지별_급성심정지환자_시행종류.csv

# %%
# 데이터 불러오기
# 환자발생지(환자발생지_시도를 '서울'로 전처리하고 환자발생지_시군구가 '소재지'인 데이터) 급성심정지환자 데이터 불러오기 
# index_col = 0 : 첫 번째 컬럼을 index로 사용하도록 지정하여 로드 
data1 = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_성별.csv",index_col = 0)
data2 = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_연령대.csv",index_col = 0)
data3 = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_급성심정지환자수.csv",index_col = 0)
data4 = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_발생장소.csv",index_col = 0)
data5 = pd.read_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_시행종류.csv",index_col = 0)

# %%
df = pd.merge(data1, data2 , on='발생지소재지', how='right')
df2 = pd.merge(df, data3 , on='발생지소재지', how='right')
df3 = pd.merge(df2, data4 , on='발생지소재지', how='right')
df4 = pd.merge(df3, data5 , on='발생지소재지', how='right')
df4
# Out:
#    발생지소재지  2018_male_count  2019_male_count  2020_male_count  male_count_mean  \
# 0     강남구              156              131              142            143.0
# 1     강동구              143              119              125            129.0
# 2     강북구              118              121              123            120.7
# 3     강서구              156              161              159            158.7
# 4     관악구              141              128              127            132.0
# 5     광진구              121               96              106            107.7
# 6     구로구              123              144              103            123.3
# 7     금천구               68               81               76             75.0
# 8     노원구              161              156              141            152.7
# 9     도봉구              127              107               97            110.3
# 10   동대문구              126              115              123            121.3
# ...

# %%
# 저장 후 주석처리 
# df4.to_csv("C:/sooeun/DATAexam/전공프로젝트(빅데이터)/data/서울시_환자발생지별_급성심정지환자_최종.csv")
